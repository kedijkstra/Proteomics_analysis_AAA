# %% [markdown]
# ## EDA of AAA meta data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from collections import Counter

# %% [markdown]
# ### Load data

# %%
meta_data = pd.read_csv("C:/Users/keimp/AAA_AMC/data/plasma_proteomics_meta_file_rawDataCSV.csv", delimiter=";")
meta_data.head()
# Out:
#   Sample_index  Measurement_index Proposed_batch Inclusion Date_surgery  \
# 0     Sample 2                  2             B1   Include          NaN
# 1     Sample 3                  3             B1   Include          NaN
# 2     Sample 7                  8             B1   Include          NaN
# 3     Sample 8                 10             B1   Include          NaN
# 4    Sample 10                 13             B1   Include          NaN
#
#         Date_processed       Pathology SimplePathology Sex   Age  ...  \
# 0  2019-11-29 00:00:00             AAA             AAA   F  76.0  ...
# 1  2019-12-11 00:00:00  Myocotisch AAA             AAA   M  69.0  ...
# 2  2020-04-28 00:00:00             AAA             AAA   M  63.0  ...
# 3  2020-06-17 00:00:00             AAA             AAA   F  73.0  ...
# 4  2020-09-14 00:00:00             AAA             AAA   F  74.0  ...
#
#   Clinical presentation Angio related familial history Post OP growth (WIP)  \
# ...

# %%
#Remove controls
meta_data = meta_data[meta_data.SimplePathology != "Control"]
#Check results
print(meta_data["SimplePathology"].unique())
# Out:
# ['AAA']

# %% [markdown]
# #### Missing values

# %%
cols = ['Pathology', 'SimplePathology', 'Sex',
       'Age', 'BMI', 'Size_AA', 'Smoking', 'Years_to_quitting', 'Diabetes',
       'DM_meds', 'Hypertension', 'HyperCholstero', 'Previous_vascu_surgery',
       'Renal_dysfunction', 'Clinical presentation',
       'Angio related familial history', 'Post OP growth (WIP)',
       'Type Aneurysms']
data = []
for c in cols:
    data.append(meta_data[c].isna().sum())

fig, ax = plt.subplots()
ax.bar(cols, data, color=["#2ca02c"])

ax.set_ylabel("Number of missing values")
ax.set_title("Missing values per column")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Pathology

# %%
print(dict(meta_data["Pathology"].value_counts()))
# Out:
# {'AAA': 62, 'Myocotisch AAA': 3, 'AAA distaal': 1, 'Iliac aneurysm': 1, 'AAA Marfan': 1, 'rAAA': 1}

# %%
data = dict(meta_data["Pathology"].value_counts())

fig, ax = plt.subplots()
ax.pie(data.values(), labels=data.keys(), autopct='%1.1f%%',
      colors=["#2ca02c","#d62728","#9467bd", "#8c564b", "#7f7f7f", "#e377c2"])
ax.set_title("AAA pathologies")
plt.show()

# %% [markdown]
# #### Sex

# %%
data = dict(meta_data["Sex"].value_counts())

fig, ax = plt.subplots()
ax.pie(data.values(), labels=data.keys(), autopct='%1.1f%%',
      colors=["#2ca02c","#d62728"])
ax.set_title("Male-female ratio in AAA")
plt.show()

# %% [markdown]
# #### Age

# %%
fig, ax = plt.subplots()
ax.hist(meta_data["Age"], color=["#2ca02c"] ,edgecolor='black', bins=30)
ax.set_title("Age distribution in AAA")
ax.set_ylabel("number of participants")
ax.set_xlabel("age (years)")
plt.show()

# %% [markdown]
# #### BMI

# %%
data = [list(meta_data[meta_data.Sex == "M"]["BMI"]),
       list(meta_data[meta_data.Sex == "F"]["BMI"])]
for n in range(len(data)):
    data[n] = [float(str(x).replace(',', '.'))  for x in data[n] if str(x) != "nan"]

labels = ["Male", "Female"]

fig, ax = plt.subplots()
bplot = ax.boxplot(data, patch_artist=True)
ax.set_xticklabels(labels)
ax.set_title("BMI in AAA")
ax.set_ylabel("body mass index (Kg/M2)")

for patch, color in zip(bplot['boxes'], ["#2ca02c","#d62728"]):
    patch.set_facecolor(color)
plt.show()

# %% [markdown]
# #### AA size

# %%
data = [list(meta_data[meta_data.Sex == "M"]["Size_AA"]),
       list(meta_data[meta_data.Sex == "F"]["Size_AA"])]
for n in range(len(data)):
    data[n] = [float(str(x).replace(',', '.')) for x in data[n] if str(x) != "nan"]

labels = ["Male", "Female"]

fig, ax = plt.subplots()
bplot = ax.boxplot(data, patch_artist=True)
ax.set_xticklabels(labels)
ax.set_ylabel("AA size (mm)")

for patch, color in zip(bplot['boxes'], ["#2ca02c","#d62728"]):
    patch.set_facecolor(color)
plt.show()

# %%
data = [float(str(x).replace(',', '.')) for x in meta_data["Size_AA"] if str(x) != "nan"]

fig, ax = plt.subplots()
ax.hist(data, color=["#2ca02c"] ,edgecolor='black', bins=20)
ax.set_title("AAA size distribution")
ax.set_ylabel("number of participants")
ax.set_xlabel("AAA size (mm)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Smoking

# %%
data = Counter([x.split(" ")[0] for x in meta_data["Smoking"]])

fig, ax = plt.subplots()
ax.pie(data.values(), labels=data.keys(), autopct='%1.1f%%',
      colors=["#2ca02c","#d62728", "#1f77b4", "#9467bd"])
ax.set_title("Smoking status in AAA")
plt.show()

# %% [markdown]
# #### Diabetes

# %%
data = dict(meta_data["Diabetes"].value_counts())

fig, ax = plt.subplots()
ax.pie(data.values(), labels=data.keys(), autopct='%1.1f%%',
      colors=["#2ca02c","#d62728"])
ax.set_title("Diabetes in AAA")
plt.show()

# %% [markdown]
# #### Diabetes medication

# %%
data = dict(meta_data["DM_meds"].value_counts())

fig, ax = plt.subplots()
ax.pie(data.values(), labels=data.keys(), autopct='%1.1f%%',
      colors=["#2ca02c","#d62728", "#1f77b4", "#9467bd", "#8c564b"])
ax.set_title("Diabetes medication in AAA")
plt.show()

# %% [markdown]
# #### Hypertension

# %%
data = dict(meta_data["Hypertension"].value_counts())

fig, ax = plt.subplots()
ax.pie(data.values(), labels=data.keys(), autopct='%1.1f%%',
      colors=["#2ca02c","#d62728"])
ax.set_title("Hypertension in AAA")
plt.show()

# %% [markdown]
# #### Hypercholesterolemia

# %%
data = dict(meta_data["HyperCholstero"].value_counts())

fig, ax = plt.subplots()
ax.pie(data.values(), labels=data.keys(), autopct='%1.1f%%',
      colors=["#d62728", "#2ca02c"])
ax.set_title("Hypercholesterolemia in AAA")
plt.show()

# %% [markdown]
# #### Previous vascular surgery

# %%
data = dict(meta_data["Previous_vascu_surgery"].value_counts())

fig, ax = plt.subplots()
ax.pie(data.values(), labels=data.keys(), autopct='%1.1f%%',
      colors=["#d62728", "#2ca02c"])
ax.set_title("Previous vascular surgery in AAA")
plt.show()

# %% [markdown]
# #### Renal dysfunction

# %%
data = dict(meta_data["Renal_dysfunction"].value_counts())

fig, ax = plt.subplots()
ax.pie(data.values(), labels=data.keys(), autopct='%1.1f%%',
      colors=["#d62728", "#2ca02c"])
ax.set_title("Renal dysfunction in AAA")
plt.show()

# %% [markdown]
# #### Clinical presentation

# %%
data = dict(meta_data["Clinical presentation"].value_counts())

fig, ax = plt.subplots()
ax.pie(data.values(), labels=data.keys(), autopct='%1.1f%%',
      colors=["#d62728", "#2ca02c", "#1f77b4", "#9467bd"])
ax.set_title("Clinical presentation in AAA")
plt.show()

# %% [markdown]
# #### Angio related familial history

# %%
data = dict(meta_data["Angio related familial history"].value_counts())

fig, ax = plt.subplots()
ax.pie(data.values(), labels=data.keys(), autopct='%1.1f%%',
      colors=["#1f77b4", "#ff7f0e","#2ca02c","#d62728","#9467bd","#8c564b","#e377c2",])
ax.set_title("Angio related familial history in AAA")
plt.show()

# %% [markdown]
# #### Post OP growth (WIP)

# %%
data = dict(meta_data["Post OP growth (WIP)"].value_counts())

fig, ax = plt.subplots()
ax.pie(data.values(), labels=data.keys(), autopct='%1.1f%%',
      colors=["#1f77b4", "#ff7f0e","#2ca02c","#d62728","#9467bd","#8c564b","#e377c2","#7f7f7f"])
ax.set_title("Post OP growth (WIP) in AAA")
plt.show()

# %% [markdown]
# #### Aneurysm type

# %%
data = dict(meta_data["Type Aneurysms"].value_counts())

fig, ax = plt.subplots()
ax.pie(data.values(), labels=data.keys(), autopct='%1.1f%%',
      colors=["#1f77b4", "#ff7f0e","#2ca02c","#d62728"])
ax.set_title("Aneurysm types")
plt.show()

# %% [markdown]
# ### Correlations

# %% [markdown]
# #### BMI and AA size

# %%
bmi = list(meta_data["BMI"])
aa_size = list(meta_data["Size_AA"])
sex = list(meta_data["Sex"])
bmi_m = []
aa_size_m = []
bmi_f = []
aa_size_f = []

for n in range(len(bmi)):
    if str(bmi[n]) != "nan" and str(aa_size[n]) != "nan":
        if sex[n] == "M":
            bmi_m.append(float(str(bmi[n]).replace(',', '.')))
            aa_size_m.append(float(str(aa_size[n]).replace(',', '.')))
        if sex[n] == "F":
            bmi_f.append(float(str(bmi[n]).replace(',', '.')))
            aa_size_f.append(float(str(aa_size[n]).replace(',', '.')))

fig, ax = plt.subplots()
ax.scatter(aa_size_m, bmi_m, c=["#2ca02c"], label="Male")
ax.scatter(aa_size_f, bmi_f, c=["#d62728"], label="Female")
ax.set_title("BMI and AA size")
ax.set_xlabel("AA size (mm)")
ax.set_ylabel("body mass index (Kg/M2)")
ax.legend()
plt.show()

# %% [markdown]
# #### Smoking and AA size

# %%
smoking = Counter([x.split(" ")[0] for x in meta_data["Smoking"]])
data = []

for i in smoking.keys():
    data.append([float(str(j).replace(',', '.')) for j in meta_data[meta_data.Smoking.str.startswith(i)]["Size_AA"] if str(j) != "nan"])

fig, ax = plt.subplots()
bplot = ax.boxplot(data, patch_artist=True)
ax.set_xticklabels(smoking.keys())
ax.set_title("Smoking status and AA size")
ax.set_ylabel("AA size (mm)")

for patch, color in zip(bplot['boxes'], ["#2ca02c","#d62728", "#1f77b4","#9467bd"]):
    patch.set_facecolor(color)
plt.show()

# %% [markdown]
# #### Age and AA size

# %%
age = list(meta_data["Age"])
aa_size = list(meta_data["Size_AA"])
age_ = []
aa_size_ = []

for n in range(len(aa_size)):
    if str(age[n]) != "nan" and str(aa_size[n]) != "nan":
        age_.append(float(str(age[n]).replace(',', '.')))
        aa_size_.append(float(str(aa_size[n]).replace(',', '.')))

fig, ax = plt.subplots()
ax.scatter(age_, aa_size_, c=["#2ca02c"])
ax.set_title("age and AA size")
ax.set_ylabel("AA size (mm)")
ax.set_xlabel("age (years)")

b, a = np.polyfit(age_, aa_size_, deg=1)
xseq = np.linspace(40, 90, num=100)
ax.plot(xseq, a + b * xseq, color="k", lw=2.5)

plt.show()
